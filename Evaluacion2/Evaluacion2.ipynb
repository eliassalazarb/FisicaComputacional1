# %% [markdown]
# <a href="https://colab.research.google.com/github/eliassalazarb/FisicaComputacional1/blob/main/Evaluacion2/Evaluacion2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Evalución 2**

# %%
#Bibliotecas
import numpy as np
from scipy import integrate, linalg
import pylab as pl
import matplotlib.pyplot as plt
import scipy.linalg as la
from scipy.integrate import odeint, solve_ivp
from numpy.linalg import matrix_power as mpow

# %%
#Función del oscilador
def oscilador(y,t,omega_c,zeta,m,f0,omega):
  pos, vel = y
  dydt = [vel, f0*np.sin(omega*t)/m - 2.0*zeta*omega_c*vel-omega_c**2*pos]
  return dydt

# %% [markdown]
# **Problema 1**

# %%
#Definimos las constantes
m = 1
f0 = 0
k = 9
omega_c = np.sqrt(k/m)
omega = 0

z1 = 0
z2 = 0.2
z3 = 0.4
z4 = 0.7
z5 = 1
z6 = 2

t = np.linspace(0,3*np.pi,500)
y0 = [-1.0,0.0]

#Obtenemos las soluciones
s1 = odeint(oscilador, y0, t, args=(omega_c, z1, m, f0, omega))
s2 = odeint(oscilador, y0, t, args=(omega_c, z2, m, f0, omega))
s3 = odeint(oscilador, y0, t, args=(omega_c, z3, m, f0, omega))
s4 = odeint(oscilador, y0, t, args=(omega_c, z4, m, f0, omega))
s5 = odeint(oscilador, y0, t, args=(omega_c, z5, m, f0, omega))
s6 = odeint(oscilador, y0, t, args=(omega_c, z6, m, f0, omega))

plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador amortiguado sin forzamiento")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()

plt.plot(t, s1[:, 0], label="zeta=0")
plt.plot(t, s2[:, 0], label="zeta=0.2")
plt.plot(t, s3[:, 0], label="zeta=0.4")
plt.plot(t, s4[:, 0], label="zeta=0.7")
plt.plot(t, s5[:, 0], label="zeta=1")
plt.plot(t, s6[:, 0], label="zeta=2")

plt.legend(loc="best")
plt.show()

# %% [markdown]
# **Problema 2**

# %%
#Definimos las constantes
zeta = 0
f0 = 1
m = 1
k = 9
omega_c = np.sqrt(k/m)

omega1 = 3
omega2 = 3.1
omega3 = 3.3
omega4 = 3.5

#Condiciones iniciales
y0 = [0.0,0.]

t = np.linspace(0,70,500)

#Obtenemos las soluciones
s1 = odeint(oscilador, y0, t, args=(omega_c, zeta, m, f0, omega1))
s2 = odeint(oscilador, y0, t, args=(omega_c, zeta, m, f0, omega2))
s3 = odeint(oscilador, y0, t, args=(omega_c, zeta, m, f0, omega3))
s4 = odeint(oscilador, y0, t, args=(omega_c, zeta, m, f0, omega4))

#Graficamos
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador forzado sin amortiguamiento")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()

plt.plot(t, s1[:, 0], label="omega=3")
plt.plot(t, s2[:, 0], label="omega=3.1")
plt.plot(t, s3[:, 0], label="omega=3.3")
plt.plot(t, s4[:, 0], label="omega=3.5")

plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(411)
plt.plot(t, s1[:, 0], label="omega=3")
plt.legend(loc="best")
plt.ylabel("x(t)")
plt.xlabel("t")
plt.subplot(412)
plt.plot(t, s2[:, 0], label="omega=3.1")
plt.legend(loc="best")
plt.ylabel("x(t)")
plt.xlabel("t")
plt.subplot(413)
plt.plot(t, s3[:, 0], label="omega=3.3")
plt.legend(loc="best")
plt.ylabel("x(t)")
plt.xlabel("t")
plt.subplot(414)
plt.plot(t, s4[:, 0], label="omega=3.5")
plt.legend(loc="best")

plt.ylabel("x(t)")
plt.xlabel("t")
plt.suptitle("Posición contra tiempo para el oscilador forzado sin amortiguamiento")
plt.show()

# %% [markdown]
# **Problema 3**

# %%
#Definimos las constantes
zeta = 0.1
f0 = 1
m = 1
k = 9
omega_c=np.sqrt(k/m)

omega1 = 3
omega2 = 3.1
omega3 = 3.3
omega4 = 3.5

#Condiciones iniciales
y0 = [0.,0.]

t = np.linspace(0,10,500)

#Obtenemos las soluciones
s1 = odeint(oscilador, y0, t, args=(omega_c, zeta, m, f0, omega1))
s2 = odeint(oscilador, y0, t, args=(omega_c, zeta, m, f0, omega2))
s3 = odeint(oscilador, y0, t, args=(omega_c, zeta, m, f0, omega3))
s4 = odeint(oscilador, y0, t, args=(omega_c, zeta, m, f0, omega4))

#Graficamos
plt.figure(figsize=(6,18))
plt.subplot(411)
plt.plot(s1[:,1], s1[:, 0], label="omega=3")
plt.legend(loc="best")
plt.ylabel("v(t)")
plt.xlabel("x(t)")
plt.subplot(412)
plt.plot(s2[:,1], s2[:, 0], label="omega=3.1")
plt.legend(loc="best")
plt.ylabel("v(t)")
plt.xlabel("x(t)")
plt.subplot(413)
plt.plot(s3[:,1], s3[:, 0], label="omega=3.3")
plt.legend(loc="best")
plt.ylabel("v(t)")
plt.xlabel("x(t)")
plt.subplot(414)
plt.plot(s4[:,1], s4[:, 0], label="omega=3.5")
plt.legend(loc="best")

plt.ylabel("v(t)")
plt.xlabel("x(t)")

plt.suptitle("Velocidad contra posición (plano fase) para el oscilador forzado y amortiguado")
plt.show()
